# %% [markdown]
# # All required imports and setting up constants

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
SEED_CONSTANT= 42

# %% [markdown]
# # Visualise the data and Categories available

# %%
plt.figure(figsize = (20, 20))
class_names = os.listdir('UCF-101')

for i, current_class in enumerate(class_names, 1):
    videos = os.listdir(f'UCF-101/{current_class}')
    selected_video = random.choice(videos)
    
    video_reader = cv2.VideoCapture(f'UCF-101/{current_class}/{selected_video}')
    
    _, first_frame = video_reader.read()
    video_reader.release()
    
    rgb_first_frame = cv2.cvtColor(first_frame, cv2.COLOR_BGR2RGB)
    
    plt.subplot(5, 4, i)
    plt.imshow(rgb_first_frame)
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-128041631cc6> in <module>
#      13     rgb_first_frame = cv2.cvtColor(first_frame, cv2.COLOR_BGR2RGB)
#      14
# ---> 15     plt.subplot(5, 4, i)
#      16     plt.imshow(rgb_first_frame)
#      17     plt.axis('off')
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     687                     num = int(num)
#     688                 if num < 1 or num > rows*cols:
# --> 689                     raise ValueError(
#     690                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     691                 return gs[num - 1]   # -1 due to MATLAB indexing.
#
# ValueError: num must be 1 <= num <= 20, not 21

# %% [markdown]
# # Pre-process the video files

# %%
def frameExtraction(videoPath):
